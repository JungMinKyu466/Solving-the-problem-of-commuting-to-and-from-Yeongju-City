# %%
import pandas as pd
import numpy as np

# %%
unpaid_csv_origin = pd.read_csv('unpaid_employers.csv')
print(unpaid_csv_origin)
# Out:
#            구분 성명(상호)  나이(대표자)         사업장명        업종  \
# 0    2024년 1차    감장철       54        승화중공업       제조업
# 1    2023년 1차    강경완       54      화경산업(주)       제조업
# 2    2023년 1차    강경훈       67   주식회사스페이스건우       건설업
# 3    2023년 2차    강명석       57         오성기업       제조업
# 4    2023년 1차    강봉철       56        한솔어패럴       제조업
# ..        ...    ...      ...          ...       ...
# 601  2024년 2차    황인철       55   주식회사지광건설산업       건설업
# 602  2024년 2차    황인철       55      (주)신우토건       건설업
# 603  2023년 1차    황준엽       55  주식회사비안코이탈리아      부동산업
# 604  2023년 1차    황진수       56         개인업자       건설업
# 605  2025년 1차    황홍철       63  주식회사에이원건설산전  도매 및 소매업
#
#                           주소지                   소재지       체불액(원)
# 0    경상남도 창원시 의창구 북면 운무로783번길        경북 경주시 외동읍 내외로   70,710,653
# 1            경상북도 경산시 자인면 금박로        경북 영천시 대창면 한제길  253,749,295
# 2             서울특별시 성북구 성북로7길         서울특별시 도봉구 도봉로   46,583,903
# 3            경상남도 김해시 상동면 여차로      경상남도 김해시 상동면 여차로   98,030,825
# ...

# %%
unpaid_csv_origin.columns
# Out:
# Index(['구분', '성명(상호)', '나이(대표자)', '사업장명', '업종', '주소지', '소재지', '체불액(원)'], dtype='str')

# %%
unpaid_csv_origin['구분']
# Out:
# 0      2024년 1차
# 1      2023년 1차
# 2      2023년 1차
# 3      2023년 2차
# 4      2023년 1차
#          ...
# 601    2024년 2차
# 602    2024년 2차
# 603    2023년 1차
# 604    2023년 1차
# 605    2025년 1차
# Name: 구분, Length: 606, dtype: str

# %%
unpaid_csv_origin['구분'][x=='2024년 2차']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 unpaid_csv_origin['구분'][x=='2024년 2차']
#
# NameError: name 'x' is not defined

# %%
unpaid_csv_origin[unpaid_csv_origin['구분'] == '2025년 1차']
# Out:
#            구분 성명(상호)  나이(대표자)                      사업장명  \
# 16   2025년 1차    고영팔       49                      선원건설
# 18   2025년 1차    고재갑       73                   (주)예림섬유
# 28   2025년 1차    권영출       61                (주)파노옵틱솔루션
# 34   2025년 1차    김경준       58                     재현어페럴
# 53   2025년 1차    김동철       56            H&P건설(에이치엔피건설)
# 58   2025년 1차    김민영       50            주식회사비지비미디호텔영도점
# 73   2025년 1차    김선길       76                 (주)선양종합관리
# 78   2025년 1차    김성보       60                    JCI365
# 89   2025년 1차    김승환       60       (주)위즈디자인솔루션엔코 덕수궁초밥
# 91   2025년 1차    김연수       62  주식회사아이티버스(ITVERSCO.,LTD)
# 101  2025년 1차    김영학       58                 백두아이티주식회사
# 105  2025년 1차    김완주       61                 사직국제어학당학원
# 110  2025년 1차    김용현       44                   주식회사타이틀
# 112  2025년 1차    김윤희       70                        진성
# 117  2025년 1차    김장원       67              케이티아이이앤씨주식회사
# 133  2025년 1차    김진관       38                해낸오버파워주식회사
# ...

# %%
unpaid_csv_origin['구분'].value_counts()
# Out:
# 구분
# 2024년 1차    185
# 2023년 1차    157
# 2023년 2차    121
# 2024년 2차     92
# 2025년 1차     51
# Name: count, dtype: int64
